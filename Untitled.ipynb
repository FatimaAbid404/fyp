# %%
import openpyxl
from pathlib import Path

# %%
import pandas as pd

# %%
import cv2
vidcap = cv2.VideoCapture('afghanistan.mp4')
success,image = vidcap.read()
count = 0
while(success):
  cv2.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  #print('Read a new frame: ', image)
  count += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9faf9de6c633> in <module>
#       4 count = 0
#       5 while(success):
# ----> 6   cv2.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file
#       7   success,image = vidcap.read()
#       8   #print('Read a new frame: ', image)
#
# KeyboardInterrupt:

# %%
from csv import reader
# open file in read mode
list1=[]
with open('file_name.csv', 'r') as read_obj:
    # pass the file object to reader() to get the reader object
    csv_reader = reader(read_obj)
    # Iterate over each row in the csv using reader object
    for row in csv_reader:
        # row variable is a list that represents a row in csv
      #  print(row)
        list1.append(row)

# %%
a=0
b=0
anotherlist=[]
for i in list1:
    listt=[]
    b=0
    
    for j in i:
    
        if j!= '[]':
            #list1[a]=list1[a].remove("[]")
            listt.append(j)
            print(j)
        b=b+1
    anotherlist.append(listt)
    
    a=a+1
            
           # print(j)
# Out:
# time
# label1
# label2
# label3
# label4
# label5
# label6
# label7
# label8
# label9
# label10
# label11
# label12
# label13
# label14
# label15
# label16
# label17
# label18
# label19
# label20
# label21
# label22
# label23
# label24
# label25
# label26
# label27
# label28
# label29
# label30
# label31
# label32
# label33
# label34
# label35
# label36
# label37
# label38
# label39
# label40
# label41
# label42
# label43
# label44
# label45
# label46
# label47
# label48
# label49
# label50
# label51
# 0
# 0.08 sec'
# 1
# 0.12 sec'
# 2
# 0.16 sec'
# 3
# 0.2 sec'
# 4
# 0.24 sec'
# 5
# 0.28 sec'
# 6
# 0.32 sec'
# 7
# 0.36 sec'
# 8
# 0.4 sec'
# 9
# 0.44 sec'
# 10
# 0.48 sec'
# 11
# 0.52 sec'
# 12
# 0.56 sec'
# 13
# 0.6 sec'
# 14
# 0.64 sec'
# [591,42,120,28]
# 15
# 0.68 sec'
# 16
# 0.72 sec'
# 17
# 0.76 sec'
# 18
# 0.8 sec'
# 19
# 0.84 sec'
# 20
# 0.88 sec'
# 21
# 0.92 sec'
# [29,675,429,43]
# 22
# 0.96 sec'
# [28.6301422119141,641.693237304688,429.576843261719,43.3587646484375]
# 23
# ...

# %%
anotherlist.pop(0)
# Out:
# ['',
#  'time',
#  'label1',
#  'label2',
#  'label3',
#  'label4',
#  'label5',
#  'label6',
#  'label7',
#  'label8',
#  'label9',
#  'label10',
#  'label11',
#  'label12',
#  'label13',
#  'label14',
#  'label15',
#  'label16',
#  'label17',
#  'label18',
#  'label19',
#  'label20',
#  'label21',
#  'label22',
#  'label23',
#  'label24',
#  'label25',
#  'label26',
#  'label27',
#  'label28',
#  'label29',
#  'label30',
#  'label31',
#  'label32',
#  'label33',
#  'label34',
#  'label35',
#  'label36',
#  'label37',
#  'label38',
#  'label39',
#  'label40',
#  'label41',
#  'label42',
#  'label43',
#  'label44',
#  'label45',
#  'label46',
#  'label47',
#  'label48',
#  'label49',
#  'label50',
#  'label51']

# %%
a=2
listt=[]
for i in anotherlist:
    li=[]
    b=len(i)
    a=2
   # li.append(i[0])
    while b>2 and a<b:
        print(i[a]) 
        li.append(i[a])
        a=a+1
    listt.append(li)
# Out:
# [591,42,120,28]
# [29,675,429,43]
# [28.6301422119141,641.693237304688,429.576843261719,43.3587646484375]
# [31,609,427,49]
# [29,660,388,46]
# [31.0475711822510,588.448791503906,426.960449218750,49.0922851562500]
# [29.0123176574707,639.542602539063,387.983337402344,46]
# [31.0616645812988,575.520385742188,426.952362060547,49.1563720703125]
# [29.0370922088623,626.583374023438,387.951690673828,45.9982299804688]
# [31.0772781372070,567.849365234375,426.930175781250,49.1650390625000]
# [29.0410442352295,618.917297363281,387.931243896484,46.0476684570313]
# [31.0649642944336,563.581176757813,426.943817138672,49.1830444335938]
# [29.0299453735352,614.709838867188,387.939422607422,46.0228881835938]
# [31.0564308166504,561.788391113281,426.944427490234,49.1606445312500]
# [29.0451374053955,612.826354980469,387.951385498047,46.0080566406250]
# [31.0685539245605,561.080627441406,426.912384033203,49.2177124023438]
# [29.2676181793213,612.281188964844,387.618988037109,45.9584350585938]
# ...

# %%
def Convert(string):
    string=string.replace("]", "")
    string=string.replace("[", "")
    li = list(string.split(","))
    return li

# %%
b=0
le=0
liist=[]
for i in listt:
    y=[]
    a=len(listt[b])
    le=0
    while(le<a):
        stri=listt[b][le]
        h=Convert(stri)
        y.append(h)
        le=le+1
    liist.append(y)
        
    b=b+1

# %%
inttt=[]
it=0
for i in liist:
    flo=[]
    for j in i:
        lii=[]
        for k in j:
            print(k)
            Float = float(k)
            num = int(Float)   
            lii.append(num)
        flo.append(lii)
    
    inttt.append(flo)
    it=it+1
# Out:
# 591
# 42
# 120
# 28
# 29
# 675
# 429
# 43
# 28.6301422119141
# 641.693237304688
# 429.576843261719
# 43.3587646484375
# 31
# 609
# 427
# 49
# 29
# 660
# 388
# 46
# 31.0475711822510
# 588.448791503906
# 426.960449218750
# 49.0922851562500
# 29.0123176574707
# 639.542602539063
# 387.983337402344
# 46
# 31.0616645812988
# 575.520385742188
# 426.952362060547
# 49.1563720703125
# 29.0370922088623
# 626.583374023438
# 387.951690673828
# 45.9982299804688
# 31.0772781372070
# 567.849365234375
# 426.930175781250
# 49.1650390625000
# 29.0410442352295
# 618.917297363281
# 387.931243896484
# 46.0476684570313
# 31.0649642944336
# 563.581176757813
# 426.943817138672
# 49.1830444335938
# 29.0299453735352
# 614.709838867188
# 387.939422607422
# 46.0228881835938
# 31.0564308166504
# 561.788391113281
# 426.944427490234
# 49.1606445312500
# 29.0451374053955
# 612.826354980469
# 387.951385498047
# 46.0080566406250
# 31.0685539245605
# 561.080627441406
# 426.912384033203
# 49.2177124023438
# ...

# %%
inttt[1886][0][0]
# Out:
# 99

# %%
type(inttt[1886][0][0])
# Out:
# int

# %%
from PIL import Image
import IPython.display as display

img = Image.new("RGB", (720, 720), (0, 0, 0))
img.save("frame0.png", "PNG")

# %%
display.display(Image.open("frame0.jpg"))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x720 at 0x18241FB91F0>

# %%
i=0
# importing OpenCV(cv2) module
import cv2
  
# Read RGB image
img = cv2.imread('frame187.jpg')

# Draw rectangles
# white rectangle
#while(i<2):
   # liist[24][1]
  #  cv2.rectangle(img, (10.008s, 500), (70, 48), (225, 255, 255), -1)
   # cv2.rectangle(img, (float(liist[24][i][0]), float(liist[24][i][1])), (float(liist[24][i][2]), float(liist[24][i][3])), (225, 255, 255), -1)
   # d=d-300
    #e=e-225
    #i=i+1
#31,609,427,49
#cv2.rectangle(img, (10, 500), (70, 48), (225, 255, 255), -1)
# Output img with window name as 'image'
#29,611,389,50
#32.9958381652832,557.999572753906,525.009216308594,42.0010375976563
cv2.rectangle(img, (32, 557), (525, 42), (225, 255, 255), 2)
cv2.imshow('frame0', img)
# Maintain output window utill
# user presses a key
cv2.waitKey(0)
  
# Destroying present windows on screen
cv2.destroyAllWindows()
